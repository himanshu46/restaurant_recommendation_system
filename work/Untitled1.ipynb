# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
y = pd.read_csv("../data/coord.csv")
y.head()
# Out:
#    Unnamed: 0                                            address  \
# 0           0  942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1           1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2           2  1112, Next to KIMS Medical College, 17th Cross...
# 3           3  1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4           4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
#
#                     name online_order book_table  rate  votes      location  \
# 0                  Jalsa          Yes        Yes   4.1    775  Banashankari
# 1         Spice Elephant          Yes         No   4.1    787  Banashankari
# 2        San Churro Cafe          Yes         No   3.8    918  Banashankari
# 3  Addhuri Udupi Bhojana           No         No   3.7     88  Banashankari
# 4          Grand Village           No         No   3.8    166  Basavanagudi
#
#              rest_type                        cuisines  cost_for_two  \
# ...

# %%
def lat(x):
    if np.isnan(x[13]) == True:
        print("true")
        location=x[0]
        try:
            location = re.sub("[^a-zA-Z 0-9'\.\-\s\,\&\/]","",location)
            ad = geolocator.geocode(location)
            x[13]=ad.latitude
            x[14]=ad.longitude
        except:
            ad = geolocator.geocode(x[6])
            x[13]=ad.latitude
            x[14]=ad.longitude
        finally:
            return x
    return x

# %%
lat2 = []
longit = []

def lat1(row):
    if np.isnan(row[13]) == True:
        print(row[13],row[14])
        try:
            loc = row[1]
            loc = re.sub("[^a-zA-Z 0-9'\.\-\s\,\&\/]","",loc)
            location = geolocator.geocode(loc)
            lat2.append(location.latitude)
            longit.append(location.longitude)
        except:
            try:
                print(row)
                loc = row[6]
                location = geolocator.geocode(loc)
                lat1.append(location.latitude)
                longit.append(location.longitude)
            except:
                lat2.append(np.nan)
                longit.append(np.nan)
        return 1
    else:
        lat2.append(row[13])
        longit.append(row[14])
    return 1

# %%
df2 = y.apply(lambda x : lat1(x), axis=1)
# Out:
# nan nan
# Unnamed: 0                                                        66
# address            30th Cross, 8th Main, Near Jain Temple, 4th Bl...
# name                                            Namma Brahmin's Idli
# online_order                                                     Yes
# book_table                                                        No
# rate                                                             3.6
# votes                                                             34
# location                                                   Jayanagar
# rest_type                                                Quick Bites
# cuisines                                                South Indian
# cost_for_two                                                     100
# reviews_list       [('Rated 4.0', 'RATED\n  Quite a cosy & small ...
# restaurant_type                                             Delivery
# ...

# %%
df2.isna().sum()
# Out:
# 0

# %%
len(lat2)
# Out:
# 42944

# %%
y["latitude"]=lat2

# %%
y["longitude"] = longit

# %%
y.head()
# Out:
#    Unnamed: 0                                            address  \
# 0           0  942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1           1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2           2  1112, Next to KIMS Medical College, 17th Cross...
# 3           3  1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4           4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
#
#                     name online_order book_table  rate  votes      location  \
# 0                  Jalsa          Yes        Yes   4.1    775  Banashankari
# 1         Spice Elephant          Yes         No   4.1    787  Banashankari
# 2        San Churro Cafe          Yes         No   3.8    918  Banashankari
# 3  Addhuri Udupi Bhojana           No         No   3.7     88  Banashankari
# 4          Grand Village           No         No   3.8    166  Basavanagudi
#
#              rest_type                        cuisines  cost_for_two  \
# ...

# %%
y.isna().sum()
# Out:
# Unnamed: 0            0
# address               0
# name                  0
# online_order          0
# book_table            0
# rate                  0
# votes                 0
# location              0
# rest_type             0
# cuisines              0
# cost_for_two          0
# reviews_list          0
# restaurant_type       0
# latitude           4096
# longitude          4096
# dtype: int64
