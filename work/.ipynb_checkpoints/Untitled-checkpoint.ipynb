# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("../data/score.csv",header=,delimiter="^")

# %%
df
# Out:
#       185,\416, 24th Cross, 9th Main, 2nd Stage, Banashankari, Bangalore\",Old Mumbai Ice Cream,Yes,No,3.9,38,Banashankari,Dessert Parlor,Ice Cream,150,\""  \
# 0      503,\1112, Next to KIMS Medical College, 17th ...
# 1      913,\10/3, Shamanna Garden, 22nd Main Rd, Phas...
# 2      1122,\33rd Main Road, KR Layout, JP Nagar, Ban...
# 3      1226,\Sir M Visveswaraya Road, Nyanappana Hall...
# 4      1291,\637, RBI Layout, RBI East Layout, JP Nag...
# ...                                                  ...
# 40529  50129,\Sigma Tech Park, Near Varthur Lake, Var...
# 40530  50693,\ITPL Basement, ITPL Main Road, Whitefie...
# 40531  50947,\G1022, Ardente Office One, Hoodi, White...
# 40532  51012,\Tower 5, Prestige Tranquility, Budhiger...
# 40533  51279,\Lower Ground Floor, Pheonix Market City...
#
#        0.29387462797619046
# 0                 0.292905
# 1                -0.041183
# 2                 0.249715
# 3                 0.350833
# 4                 0.456778
# ...

# %%
df.to_json("../data/coordjson.json")

# %%
df1 = pd.read_csv("../data/coord.csv")

# %%
df1
# Out:
#        Unnamed: 0                                            address  \
# 0               0  942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1               1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2               2  1112, Next to KIMS Medical College, 17th Cross...
# 3               3  1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4               4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...           ...                                                ...
# 42939       51709  136, SAP Labs India, KIADB Export Promotion In...
# 42940       51711  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 42941       51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 42942       51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 42943       51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# ...

# %%
df1.to_csv("../data/coord_caret",sep='^')
