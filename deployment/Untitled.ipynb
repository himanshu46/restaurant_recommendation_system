# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("flask123.csv")
df1 = pd.read_csv("score.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  \
# 0         0.0           0.0
# 1         1.0           1.0
# 2         2.0           2.0
# 3         3.0           3.0
# 4         4.0           4.0
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table  rate  votes      location            rest_type  \
# 0          Yes        Yes   4.1  775.0  Banashankari        Casual Dining
# 1          Yes         No   4.1  787.0  Banashankari        Casual Dining
# 2          Yes         No   3.8  918.0  Banashankari  Cafe, Casual Dining
# ...

# %%
df1["cluster"]=df["cluster"]

# %%
df1.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  \
# 0           0             0
# 1           1             1
# 2           2             2
# 3           3             3
# 4           4             4
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table  rate  votes      location            rest_type  \
# 0          Yes        Yes   4.1    775  Banashankari        Casual Dining
# 1          Yes         No   4.1    787  Banashankari        Casual Dining
# 2          Yes         No   3.8    918  Banashankari  Cafe, Casual Dining
# ...

# %%
df1.to_csv("final.csv")

# %%
df2 = df1.groupby(by=["name","address"]).mean(["rate","votes","cost_for_two","score"])
df2.head()
# Out:
#                                                                                            Unnamed: 0  \
# name                                 address
# #FeelTheROLL                         Opposite Mantri Commercio, Outer Ring Road, Dev...  22462.500000
# #L-81 Cafe                           Sector 6, HSR Layout, HSR                           19717.333333
# #refuel                              7, Ground Floor, RR Commercial Complex, Akshay ...   1164.000000
# 1000 B.C                             16, 17th A Main, Koramangala 5th Block, Bangalore   21321.000000
# 100ÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ°C 688, Thanish Corner, 7th Main, 10th Cross, 2nd ...  15574.000000
#
#                                                                                          Unnamed: 0.1  \
# name                                 address
# #FeelTheROLL                         Opposite Mantri Commercio, Outer Ring Road, Dev...  26916.000000
# ...

# %%
df3 = df2.reset_index()

# %%
df3.head()
# Out:
#                                    name  \
# 0                          #FeelTheROLL
# 1                            #L-81 Cafe
# 2                               #refuel
# 3                              1000 B.C
# 4  100ÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ°C
#
#                                              address    Unnamed: 0  \
# 0  Opposite Mantri Commercio, Outer Ring Road, De...  22462.500000
# 1                          Sector 6, HSR Layout, HSR  19717.333333
# 2  7, Ground Floor, RR Commercial Complex, Akshay...   1164.000000
# 3  16, 17th A Main, Koramangala 5th Block, Bangalore  21321.000000
# 4  688, Thanish Corner, 7th Main, 10th Cross, 2nd...  15574.000000
#
#    Unnamed: 0.1  rate  votes  cost_for_two   latitude  longitude  \
# 0  26916.000000   3.4    7.0         200.0  12.932102  77.685181
# 1  23666.555556   3.9   48.0         400.0  12.916542  77.651955
# 2   1348.000000   3.7   37.0         400.0  12.976747  77.575279
# ...

# %%
df3.shape
# Out:
# (10018, 12)

# %%
df3.to_csv("final1.csv")

# %%
df3.head()
# Out:
#                                    name  \
# 0                          #FeelTheROLL
# 1                            #L-81 Cafe
# 2                               #refuel
# 3                              1000 B.C
# 4  100ÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ°C
#
#                                              address    Unnamed: 0  \
# 0  Opposite Mantri Commercio, Outer Ring Road, De...  22462.500000
# 1                          Sector 6, HSR Layout, HSR  19717.333333
# 2  7, Ground Floor, RR Commercial Complex, Akshay...   1164.000000
# 3  16, 17th A Main, Koramangala 5th Block, Bangalore  21321.000000
# 4  688, Thanish Corner, 7th Main, 10th Cross, 2nd...  15574.000000
#
#    Unnamed: 0.1  rate  votes  cost_for_two   latitude  longitude  \
# 0  26916.000000   3.4    7.0         200.0  12.932102  77.685181
# 1  23666.555556   3.9   48.0         400.0  12.916542  77.651955
# 2   1348.000000   3.7   37.0         400.0  12.976747  77.575279
# ...
