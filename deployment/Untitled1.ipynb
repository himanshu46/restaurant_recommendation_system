# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("final1.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                                  name  \
# 0           0                          #FeelTheROLL
# 1           1                            #L-81 Cafe
# 2           2                               #refuel
# 3           3                              1000 B.C
# 4           4  100ÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ°C
#
#                                              address  Unnamed: 0.1  \
# 0  Opposite Mantri Commercio, Outer Ring Road, De...  22462.500000
# 1                          Sector 6, HSR Layout, HSR  19717.333333
# 2  7, Ground Floor, RR Commercial Complex, Akshay...   1164.000000
# 3  16, 17th A Main, Koramangala 5th Block, Bangalore  21321.000000
# 4  688, Thanish Corner, 7th Main, 10th Cross, 2nd...  15574.000000
#
#    Unnamed: 0.1.1  rate  votes  cost_for_two   latitude  longitude  \
# 0    26916.000000   3.4    7.0         200.0  12.932102  77.685181
# 1    23666.555556   3.9   48.0         400.0  12.916542  77.651955
# ...

# %%
coord = df.drop(["Unnamed: 0","name","address","Unnamed: 0.1","Unnamed: 0.1.1","rate","votes","cost_for_two","polarity_score","score","cluster"],axis=1)

# %%
type(coord)
# Out:
# pandas.core.frame.DataFrame

# %%
coord
# Out:
#         latitude  longitude
# 0      12.932102  77.685181
# 1      12.916542  77.651955
# 2      12.976747  77.575279
# 3      12.934656  77.623220
# 4      12.919468  77.615494
# ...          ...        ...
# 10013  12.962545  77.642771
# 10014  12.958029  77.744308
# 10015  12.917018  77.673182
# 10016  12.969846  77.751038
# 10017  12.953823  77.641134
#
# [10018 rows x 2 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-3ce1f26e470d> in <module>
# ----> 1 coord["coordinates"] = [[x[0],x[1]] for x in coord]
#
# c:\users\prati\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3161         else:
#    3162             # set column
# -> 3163             self._set_item(key, value)
#    3164
#    3165     def _setitem_slice(self, key: slice, value):
#
# c:\users\prati\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3240         """
#    3241         self._ensure_valid_index(value)
# -> 3242         value = self._sanitize_column(key, value)
#    3243         NDFrame._set_item(self, key, value)
#    3244
#
# ...

# %%
def ls(x):
    return [x[1],x[0]]

# %%
df["coordinates"] = coord.apply(lambda x: ls(x),axis=1)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'name', 'address', 'Unnamed: 0.1', 'Unnamed: 0.1.1',
#        'rate', 'votes', 'cost_for_two', 'latitude', 'longitude',
#        'polarity_score', 'score', 'cluster', 'coordinates'],
#       dtype='object')

# %%
df.drop(['Unnamed: 0','Unnamed: 0.1','Unnamed: 0.1.1'],axis=1,inplace=True)

# %%
df.head(6)
# Out:
#                                    name  \
# 0                          #FeelTheROLL
# 1                            #L-81 Cafe
# 2                               #refuel
# 3                              1000 B.C
# 4  100ÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ°C
# 5            11 to 11 Express Biriyanis
#
#                                              address  rate  votes  \
# 0  Opposite Mantri Commercio, Outer Ring Road, De...   3.4    7.0
# 1                          Sector 6, HSR Layout, HSR   3.9   48.0
# 2  7, Ground Floor, RR Commercial Complex, Akshay...   3.7   37.0
# 3  16, 17th A Main, Koramangala 5th Block, Bangalore   3.2   49.0
# 4  688, Thanish Corner, 7th Main, 10th Cross, 2nd...   3.7   41.0
# 5  Near Velankani Bus Stop, Electroniccity Phase ...   3.5   22.0
#
#    cost_for_two   latitude  longitude  polarity_score      score   cluster  \
# 0         200.0  12.932102  77.685181        0.167813   3.993937  1.000000
# ...

# %%
df.name.unique()
# Out:
# array(['#FeelTheROLL', '#L-81 Cafe', '#refuel', ..., 'iSpice Resto Cafe',
#        'nu.tree', 're:cess - Hilton Bangalore Embassy GolfLinks'],
#       dtype=object)

# %%
df.drop(['longitude','latitude'],axis=1,inplace=True)

# %%
df.head()
# Out:
#                                    name  \
# 0                          #FeelTheROLL
# 1                            #L-81 Cafe
# 2                               #refuel
# 3                              1000 B.C
# 4  100ÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ°C
#
#                                              address  rate  votes  \
# 0  Opposite Mantri Commercio, Outer Ring Road, De...   3.4    7.0
# 1                          Sector 6, HSR Layout, HSR   3.9   48.0
# 2  7, Ground Floor, RR Commercial Complex, Akshay...   3.7   37.0
# 3  16, 17th A Main, Koramangala 5th Block, Bangalore   3.2   49.0
# 4  688, Thanish Corner, 7th Main, 10th Cross, 2nd...   3.7   41.0
#
#    cost_for_two  polarity_score      score  \
# 0         200.0        0.167813   3.993937
# 1         400.0        0.283506  53.072359
# 2         400.0        0.240556  32.932056
# 3         300.0        0.118605  18.597333
# 4         450.0        0.149773  22.720553
#
#                                coordinates
# ...

# %%
df.to_csv("coordinates_data.csv",index=False)

# %%
df.drop(['cluster'],axis=1,inplace=True)

# %%
df
# Out:
#                                                name  \
# 0                                      #FeelTheROLL
# 1                                        #L-81 Cafe
# 2                                           #refuel
# 3                                          1000 B.C
# 4              100ÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ°C
# ...                                             ...
# 10013                             iSpice Resto Cafe
# 10014                                       nu.tree
# 10015                                       nu.tree
# 10016                                       nu.tree
# 10017  re:cess - Hilton Bangalore Embassy GolfLinks
#
#                                                  address      rate  \
# 0      Opposite Mantri Commercio, Outer Ring Road, De...  3.400000
# 1                              Sector 6, HSR Layout, HSR  3.900000
# 2      7, Ground Floor, RR Commercial Complex, Akshay...  3.700000
# ...

# %%
df.to_csv("finalized.csv",index=False)

# %%
df.isna().sum()
# Out:
# name                0
# address             0
# rate                0
# votes               0
# cost_for_two        0
# latitude          411
# longitude         411
# polarity_score      0
# score               0
# dtype: int64

# %%
df1 = pd.read_csv("flask123.csv")

# %%
df1
# Out:
#        Unnamed: 0  Unnamed: 0.1  \
# 0             0.0           0.0
# 1             1.0           1.0
# 2             2.0           2.0
# 3             3.0           3.0
# 4             4.0           4.0
# ...           ...           ...
# 41950     42939.0       51709.0
# 41951     42940.0       51711.0
# 41952     42941.0       51712.0
# 41953     42942.0       51715.0
# 41954     42943.0       51716.0
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 41950  136, SAP Labs India, KIADB Export Promotion In...
# 41951  139/C1, Next To GR Tech Park, Pattandur Agraha...
# ...

# %%
df2 = pd.read_csv("final.csv")
df3 = pd.read_csv("score.csv")

# %%
df2.isna().sum()
# Out:
# Unnamed: 0            0
# Unnamed: 0.1          0
# Unnamed: 0.1.1        0
# address               0
# name                  0
# online_order          0
# book_table            0
# rate                  0
# votes                 0
# location              0
# rest_type             0
# cuisines              0
# cost_for_two          0
# reviews_list          0
# restaurant_type       0
# latitude           4096
# longitude          4096
# polarity_score        0
# score                 0
# cluster             989
# dtype: int64

# %%
df3.isna().sum()
# Out:
# Unnamed: 0            0
# Unnamed: 0.1          0
# address               0
# name                  0
# online_order          0
# book_table            0
# rate                  0
# votes                 0
# location              0
# rest_type             0
# cuisines              0
# cost_for_two          0
# reviews_list          0
# restaurant_type       0
# latitude           4096
# longitude          4096
# polarity_score        0
# score                 0
# dtype: int64
